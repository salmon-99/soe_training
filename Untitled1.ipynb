# %%
# data cleaning

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load the data

# %%
df = sns.load_dataset("titanic")
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = sns.load_dataset("titanic")
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\seaborn\utils.py:579, in load_dataset(name, cache, data_home, **kws)
#     576 else:
#     577     full_path = url
# --> 579 df = pd.read_csv(full_path, **kws)
#     581 if df.iloc[-1].isnull().all():
#     582     df = df.iloc[:-1]
#
# ...
